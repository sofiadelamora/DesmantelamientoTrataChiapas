# %%
import networkx as nx
import matplotlib.pyplot as plt
import warnings; warnings.simplefilter('ignore')
import statistics 
from statistics import mean

# %%
N =nx.read_edgelist("Datos.txt", create_using = nx.Graph(), nodetype=int)
import xlrd
di = {}
wk = xlrd.open_workbook('labels.xls')
hoja = wk.sheet_by_index(0)   
for i in range(34):
    nodo = hoja.cell(i,0).value
    clave = hoja.cell(i,1).value
    di[nodo] = clave
N = nx.relabel_nodes(N, di)
sorted(N)
print(nx.info(N))
nx.draw(N, with_labels=1)
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 34
# Number of edges: 225
# Average degree:  13.2353

# %%
#Métricas

# %%
##Grado de cada nodo
gradoC=nx.degree(N)
##Excentricidad
ecc = nx.eccentricity(N)
##Centralidad de cercanía
cercania = nx.closeness_centrality(N)
##Centralidad de intermediación
intermediacion = nx.betweenness_centrality(N)
##Coeficiente de Clustering
clustering = nx.clustering(N) ###the clustering of a node u is the fraction of possible triangles through that node that exist
##Centralidad de eigenvector
eigenvector = nx.eigenvector_centrality(N)
##Densidad
densidad = nx.density(N)

# %%
cercania
# Out:
# {'Cu1': 0.5892857142857143,
#  'Cu2': 0.5892857142857143,
#  'Cu3': 0.5892857142857143,
#  'Et1': 0.6875,
#  'Et2': 0.6875,
#  'Ex1': 0.8461538461538461,
#  'Ex2': 0.66,
#  'Pa1': 0.8461538461538461,
#  'Pa3': 0.6346153846153846,
#  'Ra1': 0.6111111111111112,
#  'Ra2': 0.6226415094339622,
#  'Ra3': 0.6226415094339622,
#  'VR1': 0.7021276595744681,
#  'VR2': 0.66,
#  'Cu4': 0.5238095238095238,
#  'Cu5': 0.5689655172413793,
#  'Cu6': 0.5409836065573771,
#  'Em2': 0.5689655172413793,
#  'Et3': 0.66,
#  'Ex3': 0.6470588235294118,
#  'Ra4': 0.5789473684210527,
#  'Ra5': 0.5789473684210527,
#  'Re3': 0.6875,
#  'Fu1': 0.6111111111111112,
#  'Fu2': 0.6111111111111112,
#  'Em1': 0.559322033898305,
#  'Gu3': 0.5689655172413793,
#  'Es1': 0.5,
#  'Es2': 0.375,
#  'Gu1': 0.559322033898305,
#  'Gu2': 0.559322033898305,
#  'Re1': 0.66,
#  'Re2': 0.6111111111111112,
#  'Pa2': 0.5789473684210527}

# %%
#Graficas de características

# %%
##Distribución de los grados
def dist_grados(N):
    mis_grados = nx.degree(N)
    grados = [v for k, v in mis_grados]
    unicos = list(set(grados))
    
    numero_grados=[]
    
    for i in unicos:
        conteo = grados.count(i)
        numero_grados.append(conteo)
    plt.plot(unicos, numero_grados)
    plt.show
dist_grados(N)

# %%
##Excentricidad
distribuir_nodos = nx.spring_layout(N)
color = [1000.0 * N.degree(v) for v in N]
tamaño = [v * 500 for v in ecc.values()]
plt.figure(figsize=(15,15))
nx.draw_networkx(N, pos=distribuir_nodos , with_labels=1,node_color=color, node_size=tamaño)
plt.axis('off')
sorted(ecc, key=ecc.get, reverse=1)
# Out:
# ['Cu1',
#  'Cu2',
#  'Cu3',
#  'Et1',
#  'Et2',
#  'Ex2',
#  'Pa3',
#  'Ra1',
#  'Ra2',
#  'Ra3',
#  'VR1',
#  'VR2',
#  'Cu4',
#  'Cu5',
#  'Cu6',
#  'Em2',
#  'Et3',
#  'Ex3',
#  'Ra4',
#  'Ra5',
#  'Fu1',
#  'Fu2',
#  'Em1',
#  'Es1',
#  'Es2',
#  'Re2',
#  'Pa2',
#  'Ex1',
#  'Pa1',
#  'Re3',
#  'Gu3',
#  'Gu1',
#  'Gu2',
#  'Re1']

# %%
##Grado
tamaño = [v * 274 for v in cercania.values()]
plt.figure(figsize=(15,15))
nx.draw_networkx(N, pos=distribuir_nodos, with_labels=1, node_color=color, node_size=tamaño)
plt.axis('off')
sorted(cercania, key=cercania.get, reverse=1)
# Out:
# ['Ex1',
#  'Pa1',
#  'VR1',
#  'Et1',
#  'Et2',
#  'Re3',
#  'Ex2',
#  'VR2',
#  'Et3',
#  'Re1',
#  'Ex3',
#  'Pa3',
#  'Ra2',
#  'Ra3',
#  'Ra1',
#  'Fu1',
#  'Fu2',
#  'Re2',
#  'Cu1',
#  'Cu2',
#  'Cu3',
#  'Ra4',
#  'Ra5',
#  'Pa2',
#  'Cu5',
#  'Em2',
#  'Gu3',
#  'Em1',
#  'Gu1',
#  'Gu2',
#  'Cu6',
#  'Cu4',
#  'Es1',
#  'Es2']

# %%
intermediacion = nx.betweenness_centrality(N)
intermediacion
# Out:
# {'Cu1': 0.0008733164983164982,
#  'Cu2': 0.0008733164983164982,
#  'Cu3': 0.0008733164983164982,
#  'Et1': 0.026415193602693603,
#  'Et2': 0.026551226551226548,
#  'Ex1': 0.15673967762035945,
#  'Ex2': 0.008402477152477153,
#  'Pa1': 0.13291095478595477,
#  'Pa3': 0.008597132034632034,
#  'Ra1': 0.001574525012025012,
#  'Ra2': 0.0037615740740740743,
#  'Ra3': 0.0037615740740740743,
#  'VR1': 0.017353595478595475,
#  'VR2': 0.010948021885521884,
#  'Cu4': 0.002166756854256854,
#  'Cu5': 0.007417246053609691,
#  'Cu6': 0.01176271645021645,
#  'Em2': 0.005941859066859067,
#  'Et3': 0.040951998338361974,
#  'Ex3': 0.028039390113253747,
#  'Ra4': 0.00836715367965368,
#  'Ra5': 0.00836715367965368,
#  'Re3': 0.056730453889544806,
#  'Fu1': 0.00973725348725349,
#  'Fu2': 0.011966390091390089,
#  'Em1': 0.0034279483143119507,
#  'Gu3': 0.04959743539288994,
#  'Es1': 0.013722041847041847,
#  'Es2': 0.0006456611570247935,
#  'Gu1': 0.005606798504525777,
#  'Gu2': 0.003631690279417552,
#  'Re1': 0.022068903318903318,
#  'Re2': 0.007556216931216932,
#  'Pa2': 0.0034166065416065413}

# %%
mean(intermediacion[k] for k in intermediacion)
# Out:
# 0.020610516934046346

# %%
nx.average_clustering(N)
# Out:
# 0.6466983604731741

# %%
nx.density(N)
# Out:
# 0.40106951871657753

# %%
nx.diameter(N)
# Out:
# 3

# %%
mis_grados = nx.degree(N)
grados = [v for k, v in mis_grados]
unicos = list(grados)
promedio = mean(unicos)
promedio
# Out:
# 13.235294117647058

# %%
sorted(ecc.items())
# Out:
# [('Cu1', 3),
#  ('Cu2', 3),
#  ('Cu3', 3),
#  ('Cu4', 3),
#  ('Cu5', 3),
#  ('Cu6', 3),
#  ('Em1', 3),
#  ('Em2', 3),
#  ('Es1', 3),
#  ('Es2', 3),
#  ('Et1', 3),
#  ('Et2', 3),
#  ('Et3', 3),
#  ('Ex1', 2),
#  ('Ex2', 3),
#  ('Ex3', 3),
#  ('Fu1', 3),
#  ('Fu2', 3),
#  ('Gu1', 2),
#  ('Gu2', 2),
#  ('Gu3', 2),
#  ('Pa1', 2),
#  ('Pa2', 3),
#  ('Pa3', 3),
#  ('Ra1', 3),
#  ('Ra2', 3),
#  ('Ra3', 3),
#  ('Ra4', 3),
#  ('Ra5', 3),
#  ('Re1', 2),
#  ('Re2', 3),
#  ('Re3', 2),
#  ('VR1', 3),
#  ('VR2', 3)]

# %%
sorted(eigenvector.items())
# Out:
# [('Cu1', 0.18511102502661622),
#  ('Cu2', 0.18511102502661622),
#  ('Cu3', 0.18511102502661622),
#  ('Cu4', 0.0632611670812563),
#  ('Cu5', 0.08404524453891499),
#  ('Cu6', 0.06721753595945805),
#  ('Em1', 0.0802726709506958),
#  ('Em2', 0.08963245493395246),
#  ('Es1', 0.027834125391513153),
#  ('Es2', 0.0065803739115672345),
#  ('Et1', 0.23752949064206474),
#  ('Et2', 0.23809876940415817),
#  ('Et3', 0.18783886564593952),
#  ('Ex1', 0.2920809228941115),
#  ('Ex2', 0.2297570018636388),
#  ('Ex3', 0.16531633202886442),
#  ('Fu1', 0.16009922807901186),
#  ('Fu2', 0.14949755184593658),
#  ('Gu1', 0.06523667318673276),
#  ('Gu2', 0.07260545507366252),
#  ('Gu3', 0.07536078154709973),
#  ('Pa1', 0.29030221313992627),
#  ('Pa2', 0.13503802299920306),
#  ('Pa3', 0.1967490536346633),
#  ('Ra1', 0.18457699633392088),
#  ('Ra2', 0.19267165196085706),
#  ('Ra3', 0.19267165196085706),
#  ('Ra4', 0.10240368929265692),
#  ('Ra5', 0.10240368929265692),
#  ('Re1', 0.19459261430822733),
#  ('Re2', 0.169152125858758),
#  ('Re3', 0.19321386034359983),
#  ('VR1', 0.2564100733245226),
#  ('VR2', 0.2219163327310094)]
